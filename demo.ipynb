# %%
from virtual_biopsy import get_biopsy_from_wsi
import matplotlib.pyplot as plt
wsi_path = "WSI/example.svs"
xml_path = "WSI/example.xml"

slide = get_biopsy_from_wsi(wsi_path=wsi_path, xml_path=xml_path)
plt.imshow(slide)
plt.show()

# to save, try: slide.save("example.tiff")
